# %% [markdown]
# # testing

# %%
d=8
psi0 = qt.basis(d,0)

I[-1].z
np.kron(I[-1].x, I[-1].id) - np.kron(I[-1].id, I[-1].x)

# %%
lv = qt.liouvillian(qt.Qobj(I[-1].x))

# %%
I[-1].rho(np.array(psi0))

# %%
(np.pi*lv).expm()*I[-1].rho(np.array(psi0))

# %%
model.rot

# %%
-1j*np.diag(np.kron(I[-1].z, I[-1].id) - np.kron(I[-1].id, I[-1].z))
