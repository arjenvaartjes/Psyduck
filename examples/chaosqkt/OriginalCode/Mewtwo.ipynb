# %%
import subprocess
import os

os.chdir("/Users/sean/Documents/MewtwoMegaEvo-develop/Playground")
result = subprocess.run(["./MewtwoMegaEvo"], capture_output=True, text=True)

print("OUTPUT:\n", result.stdout)
if result.stderr != '':
    print("ERRORS:\n", result.stderr)
# Out:
# OUTPUT:
#  /Users/sean/Documents/MewtwoMegaEvo-develop/Playground/config_files/GlobalX_time -> /Users/sean/Documents/MewtwoMegaEvo-develop/Playground/sim_results/DynamicalTunnelingSimulation20251203153330/config_files/GlobalX_time
# /Users/sean/Documents/MewtwoMegaEvo-develop/Playground/config_files/GlobalX_time_span -> /Users/sean/Documents/MewtwoMegaEvo-develop/Playground/sim_results/DynamicalTunnelingSimulation20251203153330/config_files/GlobalX_time_span
# /Users/sean/Documents/MewtwoMegaEvo-develop/Playground/config_files/HmwRWASbNMRAmp -> /Users/sean/Documents/MewtwoMegaEvo-develop/Playground/sim_results/DynamicalTunnelingSimulation20251203153330/config_files/HmwRWASbNMRAmp
# /Users/sean/Documents/MewtwoMegaEvo-develop/Playground/config_files/HmwRWASbNMRFreq -> /Users/sean/Documents/MewtwoMegaEvo-develop/Playground/sim_results/DynamicalTunnelingSimulation20251203153330/config_files/HmwRWASbNMRFreq
# ...
